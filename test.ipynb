# %%
x = "1"
while(x>"0"):
    x  = input()
    print("yrs")
# Out:
# d
# yrs
# d
# yrs
# d
# yrs
# 1
# yrs
# 0
# yrs

# %%
sum = 0
x = 1
while (x != 101):
    
    sum = sum+x
    x = x+2
print(sum)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14536/289409323.py in <module>
#       3 while (x != 100):
#       4
# ----> 5     sum = sum+x
#       6     x = x+2
#       7 print(sum)
#
# KeyboardInterrupt:
